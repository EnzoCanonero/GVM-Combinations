# %%
import numpy as np
import os
from scipy.optimize import minimize
from scipy.stats import gamma, chi2

import numpy as np
import matplotlib.pyplot as plt

from iminuit import Minuit
from iminuit.util import make_func_code
from GVM_combination import combination, replace_labels

import json

# %%
input_folder = "input_files_old/"

# %%
comb = 'lhc'
uncertainties = {}
top_comb = combination(input_folder, comb=comb)


systematics = ['LHCbJES', 'btag', 'ME', 'LHCJES1', 'LHCJES2', 'method', 'CMSbHad', 'LHCrad']

all_CI1 = top_comb.analyze_systematics_combination_CI(systematics, eps_end=0.6, n_points=7, ylim=(0.,0.5), output_path = 'output_files/results_new2')# bartlett_json_path='new1_bartlett/summary_results_bias_sigma.json')

# %%
comb = 'lhc'
uncertainties = {}
top_comb = combination(input_folder, comb=comb)

systematics = ['LHCbJES', 'btag', 'ME', 'LHCJES1', 'LHCJES2', 'method', 'CMSbHad', 'LHCrad']

all_CV1 = top_comb.analyze_systematics_combination_CV(systematics, eps_end=0.6, n_points=7, ylim=(172.4,172.6), output_path = 'output_files/results_new2')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
